# %% [markdown]
# <a href="https://colab.research.google.com/github/rameenhamad/Certura_ML_Internship_tasks/blob/main/2_Email_Spam_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"/content/drive/MyDrive/Certura_Tasks/spam.csv", encoding='latin1')
df.head(5)
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %% [markdown]
# Feature Engineering

# %%
#dropping null columns
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis = 1, inplace=True)
df.head(5)
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#renaming v1, v2 to appropriate names
df.rename(columns={'v1':'label', 'v2':'sms'}, inplace=True)
df.head(5)
# Out:
#   label                                                sms
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (5572, 2)

# %% [markdown]
# NLP pipeline (data cleaning)

# %%
import re
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

def clean_text(text):
  text = text.lower()
  text = re.sub(r"[^a-zA-Z\s]", '', text)
  text = re.sub(r"^https\S+|http\S+|www\S+|WWW\S+", '', text)
  text = text.split()
  text = [word for word in text if word not in ENGLISH_STOP_WORDS]
  cleanedText = " ".join(text)
  return cleanedText

df['mail_text'] = df['sms'].apply(lambda x: clean_text(x))

# %% [markdown]
# train test split

# %%
from sklearn.model_selection import train_test_split

X = df['mail_text']
Y = df['label']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=37)
Y_train.value_counts()
# Out:
# label
# ham     3860
# spam     597
# Name: count, dtype: int64

# %% [markdown]
# encoding target variable

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
Y_train = le.fit_transform(Y_train)
Y_test = le.transform(Y_test)

# %% [markdown]
# converting text to numeric values

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfid = TfidfVectorizer()
X_train_vectorize = tfid.fit_transform(X_train)
X_test_vectorize = tfid.transform(X_test)

# %% [markdown]
# balancing target variable classes

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_train_resampled, Y_train_resampled = smote.fit_resample(X_train_vectorize, Y_train)

# %% [markdown]
# model fit

# %%
from sklearn.naive_bayes import MultinomialNB

NB = MultinomialNB()
model = NB.fit(X_train_resampled, Y_train_resampled)
Y_pred = model.predict(X_test_vectorize)

# %% [markdown]
# Accuracy score

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

print("Accuracy:", accuracy_score(Y_test, Y_pred))
print(confusion_matrix(Y_test, Y_pred))
print(classification_report(Y_test, Y_pred))
# Out:
# Accuracy: 0.9668161434977578
# [[937  28]
#  [  9 141]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       965
#            1       0.83      0.94      0.88       150
#
#     accuracy                           0.97      1115
#    macro avg       0.91      0.96      0.93      1115
# weighted avg       0.97      0.97      0.97      1115

# %% [markdown]
# pipelining all the steps

# %%
def nlp_transform(X):
    return [clean_text(text) for text in X]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.metrics import accuracy_score

pipeline = Pipeline([
  ("NLP_pipeline", FunctionTransformer(nlp_transform)),
  ("Vectorizer", TfidfVectorizer(stop_words='english')),
  ("model", MultinomialNB())
])

pipe = pipeline.fit(X_train, Y_train)
Y_predict = pipe.predict(X_test)

accuracy = accuracy_score(Y_test, Y_predict)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9659192825112107

# %% [markdown]
# prediction on unseen data

# %%
def spam_check(text):
  sms = np.array([text])
  pred = pipe.predict(sms)
  return pred

t= 'i am rameen, with github https://rameen84. student of bs 3rd semester'
result = spam_check(t)
if result == 0:
  print("Not spam")
else:
  print("spam")
# Out:
# Not spam
